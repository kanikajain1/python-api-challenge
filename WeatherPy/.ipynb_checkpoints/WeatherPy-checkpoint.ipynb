# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %%
city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="


# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : ulladulla
# Processing Record 2 of Set 1 : yulara
# Processing Record 3 of Set 1 : hilo
# Processing Record 4 of Set 1 : diffa
# Processing Record 5 of Set 1 : santa cruz
# Processing Record 6 of Set 1 : castro
# Processing Record 7 of Set 1 : vostok
# Processing Record 8 of Set 1 : gallup
# Processing Record 9 of Set 1 : puerto ayora
# Processing Record 10 of Set 1 : bredasdorp
# City not found. Skipping...
# Processing Record 11 of Set 1 : rikitea
# Processing Record 12 of Set 1 : los llanos de aridane
# Processing Record 13 of Set 1 : nikolskoye
# Processing Record 14 of Set 1 : yellowknife
# Processing Record 15 of Set 1 : punta arenas
# Processing Record 16 of Set 1 : yantal
# Processing Record 17 of Set 1 : carnarvon
# Processing Record 18 of Set 1 : oktyabrskoye
# Processing Record 19 of Set 1 : vaini
# Processing Record 20 of Set 1 : elizabeth city
# Processing Record 21 of Set 1 : borgarnes
# Processing Record 22 of Set 1 : bambous virieux
# Processing Record 23 of Set 1 : reo
# Processing Record 24 of Set 1 : nome
# Processing Record 25 of Set 1 : jamestown
# Processing Record 26 of Set 1 : chokurdakh
# Processing Record 27 of Set 1 : paris
# Processing Record 28 of Set 1 : yako
# City not found. Skipping...
# Processing Record 29 of Set 1 : tuktoyaktuk
# Processing Record 30 of Set 1 : havre
# Processing Record 31 of Set 1 : touros
# Processing Record 32 of Set 1 : west wendover
# Processing Record 33 of Set 1 : hermanus
# Processing Record 34 of Set 1 : south venice
# Processing Record 35 of Set 1 : opuwo
# Processing Record 36 of Set 1 : ketchikan
# Processing Record 37 of Set 1 : avera
# Processing Record 38 of Set 1 : ucluelet
# Processing Record 39 of Set 1 : ponta do sol
# Processing Record 40 of Set 1 : marabba
# Processing Record 41 of Set 1 : bilibino
# Processing Record 42 of Set 1 : batemans bay
# Processing Record 43 of Set 1 : hithadhoo
# City not found. Skipping...
# Processing Record 44 of Set 1 : kungurtug
# Processing Record 45 of Set 1 : ushuaia
# Processing Record 46 of Set 1 : lebu
# Processing Record 47 of Set 1 : salalah
# Processing Record 48 of Set 1 : bandarbeyla
# Processing Record 49 of Set 1 : port blair
# Processing Record 50 of Set 1 : avarua
# Processing Record 0 of Set 2 : chuy
# Processing Record 1 of Set 2 : mar del plata
# Processing Record 2 of Set 2 : pisco
# Processing Record 3 of Set 2 : cape town
# City not found. Skipping...
# Processing Record 4 of Set 2 : kapaa
# Processing Record 5 of Set 2 : engerwitzdorf
# Processing Record 6 of Set 2 : tiznit
# Processing Record 7 of Set 2 : benghazi
# Processing Record 8 of Set 2 : mataura
# Processing Record 9 of Set 2 : new norfolk
# Processing Record 10 of Set 2 : rocha
# Processing Record 11 of Set 2 : saint-philippe
# Processing Record 12 of Set 2 : kangaatsiaq
# Processing Record 13 of Set 2 : kaeo
# Processing Record 14 of Set 2 : oranjestad
# Processing Record 15 of Set 2 : albany
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 2 : nalut
# Processing Record 17 of Set 2 : hasaki
# Processing Record 18 of Set 2 : port alfred
# Processing Record 19 of Set 2 : shetpe
# Processing Record 20 of Set 2 : sol-iletsk
# Processing Record 21 of Set 2 : yerbogachen
# Processing Record 22 of Set 2 : upernavik
# Processing Record 23 of Set 2 : fortuna
# Processing Record 24 of Set 2 : victoria
# Processing Record 25 of Set 2 : atuona
# Processing Record 26 of Set 2 : muroto
# Processing Record 27 of Set 2 : dikson
# Processing Record 28 of Set 2 : kaihua
# Processing Record 29 of Set 2 : wawa
# Processing Record 30 of Set 2 : baruun-urt
# Processing Record 31 of Set 2 : karratha
# Processing Record 32 of Set 2 : pevek
# Processing Record 33 of Set 2 : takaka
# Processing Record 34 of Set 2 : mokrous
# Processing Record 35 of Set 2 : leningradskiy
# Processing Record 36 of Set 2 : bethel
# Processing Record 37 of Set 2 : butaritari
# City not found. Skipping...
# Processing Record 38 of Set 2 : corsicana
# Processing Record 39 of Set 2 : saskylakh
# Processing Record 40 of Set 2 : buraydah
# Processing Record 41 of Set 2 : tasiilaq
# Processing Record 42 of Set 2 : matagami
# Processing Record 43 of Set 2 : mahanoro
# Processing Record 44 of Set 2 : kruisfontein
# Processing Record 45 of Set 2 : soc trang
# Processing Record 46 of Set 2 : brae
# Processing Record 47 of Set 2 : lompoc
# Processing Record 48 of Set 2 : christchurch
# Processing Record 49 of Set 2 : kapit
# Processing Record 50 of Set 2 : yar-sale
# Processing Record 0 of Set 3 : whyalla
# Processing Record 1 of Set 3 : bolshaya dzhalga
# Processing Record 2 of Set 3 : charlestown
# Processing Record 3 of Set 3 : airai
# Processing Record 4 of Set 3 : adrar
# Processing Record 5 of Set 3 : east london
# Processing Record 6 of Set 3 : provideniya
# Processing Record 7 of Set 3 : beloha
# Processing Record 8 of Set 3 : prosvet
# Processing Record 9 of Set 3 : busselton
# Processing Record 10 of Set 3 : thompson
# Processing Record 11 of Set 3 : roald
# Processing Record 12 of Set 3 : portland
# City not found. Skipping...
# Processing Record 13 of Set 3 : cap malheureux
# City not found. Skipping...
# Processing Record 14 of Set 3 : lethem
# Processing Record 15 of Set 3 : fort-shevchenko
# Processing Record 32 of Set 4 : baculin
# Processing Record 33 of Set 4 : haldibari
# Processing Record 34 of Set 4 : nanortalik
# Processing Record 35 of Set 4 : aklavik
# Processing Record 36 of Set 4 : nongpoh
# Processing Record 37 of Set 4 : kodiak
# Processing Record 38 of Set 4 : te anau
# Processing Record 39 of Set 4 : lumphat
# Processing Record 40 of Set 4 : saint george
# Processing Record 41 of Set 4 : trostberg
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 4 : hobbs
# City not found. Skipping...
# Processing Record 43 of Set 4 : kismayo
# Processing Record 44 of Set 4 : hualmay
# Processing Record 45 of Set 4 : aranda de duero
# Processing Record 46 of Set 4 : mwinilunga
# Processing Record 47 of Set 4 : port elizabeth
# Processing Record 48 of Set 4 : san cristobal
# Processing Record 49 of Set 4 : mehran
# Processing Record 50 of Set 4 : floro
# Processing Record 0 of Set 5 : arman
# Processing Record 1 of Set 5 : shelburne
# Processing Record 2 of Set 5 : vila
# Processing Record 3 of Set 5 : tual
# Processing Record 4 of Set 5 : davila
# Processing Record 5 of Set 5 : talnakh
# Processing Record 6 of Set 5 : agadez
# Processing Record 7 of Set 5 : ostrovnoy
# Processing Record 8 of Set 5 : morondava
# Processing Record 9 of Set 5 : warka
# Processing Record 10 of Set 5 : cikupa
# Processing Record 11 of Set 5 : norman wells
# Processing Record 12 of Set 5 : kenai
# Processing Record 13 of Set 5 : hofn
# Processing Record 14 of Set 5 : gujar khan
# Processing Record 15 of Set 5 : khatanga
# Processing Record 16 of Set 5 : lagoa
# Processing Record 17 of Set 5 : narsaq
# Processing Record 18 of Set 5 : scarborough
# City not found. Skipping...
# Processing Record 19 of Set 5 : buin
# Processing Record 20 of Set 5 : deputatskiy
# Processing Record 21 of Set 5 : puerto gaitan
# Processing Record 22 of Set 5 : maniitsoq
# Processing Record 23 of Set 5 : kendari
# Processing Record 24 of Set 5 : behshahr
# Processing Record 25 of Set 5 : hoquiam
# Processing Record 26 of Set 5 : saint-georges
# Processing Record 27 of Set 5 : ridgecrest
# Processing Record 28 of Set 5 : luderitz
# Processing Record 29 of Set 5 : korla
# Processing Record 30 of Set 5 : arraial do cabo
# Processing Record 31 of Set 5 : vao
# Processing Record 32 of Set 5 : pacifica
# Processing Record 33 of Set 5 : hobyo
# Processing Record 34 of Set 5 : labuhan
# City not found. Skipping...
# Processing Record 35 of Set 5 : bengkulu
# Processing Record 36 of Set 5 : sao domingos
# Processing Record 37 of Set 5 : cheremukhovo
# Processing Record 38 of Set 5 : breytovo
# Processing Record 39 of Set 5 : kirensk
# Processing Record 40 of Set 5 : auki
# Processing Record 41 of Set 5 : khorixas
# Processing Record 42 of Set 5 : goderich
# Processing Record 43 of Set 5 : trelew
# Processing Record 44 of Set 5 : hambantota
# Processing Record 45 of Set 5 : butler
# Processing Record 46 of Set 5 : kassala
# Processing Record 47 of Set 5 : asyut
# Processing Record 48 of Set 5 : muti
# Processing Record 49 of Set 5 : greenlaw
# Processing Record 50 of Set 5 : balkanabat
# Processing Record 0 of Set 6 : nouadhibou
# Processing Record 1 of Set 6 : mirador
# Processing Record 2 of Set 6 : gari
# Processing Record 3 of Set 6 : mae chan
# Processing Record 4 of Set 6 : trairi
# Processing Record 5 of Set 6 : honningsvag
# Processing Record 6 of Set 6 : qaanaaq
# Processing Record 7 of Set 6 : xuddur
# City not found. Skipping...
# Processing Record 8 of Set 6 : shaowu
# City not found. Skipping...
# Processing Record 9 of Set 6 : awbari
# Processing Record 10 of Set 6 : skoghall
# Processing Record 11 of Set 6 : buala
# Processing Record 12 of Set 6 : bairiki
# Processing Record 13 of Set 6 : sao filipe
# Processing Record 14 of Set 6 : port hardy
# Processing Record 15 of Set 6 : sao joao da barra
# Processing Record 16 of Set 6 : carmelo
# Processing Record 17 of Set 6 : alofi
# Processing Record 18 of Set 6 : kodinsk
# Processing Record 19 of Set 6 : saint-denis
# Processing Record 20 of Set 6 : cayenne
# Processing Record 21 of Set 6 : muscat
# Processing Record 22 of Set 6 : gambela
# Processing Record 23 of Set 6 : neiafu
# Processing Record 24 of Set 6 : necochea
# Processing Record 25 of Set 6 : longyearbyen
# Processing Record 26 of Set 6 : dudinka
# Processing Record 27 of Set 6 : miram shah
# Processing Record 28 of Set 6 : tadine
# Processing Record 29 of Set 6 : menongue
# Processing Record 30 of Set 6 : kaitangata
# Processing Record 31 of Set 6 : sena madureira
# Processing Record 32 of Set 6 : winterberg
# City not found. Skipping...
# Processing Record 33 of Set 6 : mayo
# Processing Record 34 of Set 6 : vila franca do campo
# City not found. Skipping...
# Processing Record 35 of Set 6 : california city
# Processing Record 36 of Set 6 : katangli
# Processing Record 37 of Set 6 : borogontsy
# Processing Record 38 of Set 6 : lorengau
# Processing Record 39 of Set 6 : zhigansk
# Processing Record 40 of Set 6 : erzin
# Processing Record 41 of Set 6 : kavaratti
# Processing Record 42 of Set 6 : barcelona
# Processing Record 43 of Set 6 : husavik
# Processing Record 44 of Set 6 : tiksi
# Processing Record 45 of Set 6 : caravelas
# Processing Record 46 of Set 6 : awash
# Processing Record 47 of Set 6 : esperance
# Processing Record 48 of Set 6 : alyangula
# Processing Record 49 of Set 6 : verkhnyaya inta
# Processing Record 50 of Set 6 : sitka
# Processing Record 0 of Set 7 : ostersund
# Processing Record 1 of Set 7 : sorland
# Processing Record 2 of Set 7 : lulea
# Processing Record 3 of Set 7 : makaryev
# Processing Record 4 of Set 7 : santa fe
# Processing Record 5 of Set 7 : chara
# Processing Record 6 of Set 7 : birao
# Processing Record 7 of Set 7 : souillac
# Processing Record 8 of Set 7 : shimoda
# Processing Record 9 of Set 7 : moerai
# Processing Record 10 of Set 7 : athabasca
# Processing Record 11 of Set 7 : balkhash
# City not found. Skipping...
# Processing Record 12 of Set 7 : san policarpo
# Processing Record 13 of Set 7 : walvis bay
# Processing Record 14 of Set 7 : nanning
# Processing Record 15 of Set 7 : keffi
# Processing Record 16 of Set 7 : grand forks
# Processing Record 17 of Set 7 : surgut
# Processing Record 18 of Set 7 : campulung
# Processing Record 18 of Set 11 : eyl
# Processing Record 19 of Set 11 : kayes
# Processing Record 20 of Set 11 : cherdyn
# Processing Record 21 of Set 11 : odweyne
# Processing Record 22 of Set 11 : verkhovye
# Processing Record 23 of Set 11 : bukama
# Processing Record 24 of Set 11 : barra do bugres
# Processing Record 25 of Set 11 : srednekolymsk
# Processing Record 26 of Set 11 : san vicente
# Processing Record 27 of Set 11 : arlit
# Processing Record 28 of Set 11 : sioux lookout
# Processing Record 29 of Set 11 : guasdualito
# Processing Record 30 of Set 11 : sao bernardo
# Processing Record 31 of Set 11 : port arthur
# Processing Record 32 of Set 11 : lamu
# Processing Record 33 of Set 11 : grindavik
# Processing Record 34 of Set 11 : anloga
# Processing Record 35 of Set 11 : tabou
# Processing Record 36 of Set 11 : padang
# Processing Record 37 of Set 11 : baykit
# Processing Record 38 of Set 11 : borba
# Processing Record 39 of Set 11 : sabha
# Processing Record 40 of Set 11 : pindiga
# Processing Record 41 of Set 11 : torrington
# Processing Record 42 of Set 11 : lodja
# Processing Record 43 of Set 11 : vanimo
# Processing Record 44 of Set 11 : tommot
# Processing Record 45 of Set 11 : nuuk
# Processing Record 46 of Set 11 : klyuchi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a panda data frame using data retrieved
weather_dict = pd.DataFrame({ 
                "City" : city_name_list,
                "Cloudiness" : cloudiness_list,
                "Country" : country_list,
                "Date" : date_list,
                "Humidity" : humidity_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp" : max_temp_list,
                "Wind Speed" : wind_speed_list
})

# %%
# Count data
weather_dict.count()
# Out:
# City          556
# Cloudiness    556
# Country       556
# Date          556
# Humidity      556
# Lat           556
# Lng           556
# Max Temp      556
# Wind Speed    556
# dtype: int64

# %%
# Display the Data Frame
weather_dict
# Out:
#                         City  Cloudiness Country        Date  Humidity    Lat  \
# 0                  Ulladulla          99      AU  1595628574       100 -35.35
# 1                     Yulara           0      AU  1595628574        75 -25.24
# 2                       Hilo          90      US  1595628279        69  19.73
# 3                      Diffa          13      NE  1595628574        46  13.32
# 4    Santa Cruz de la Sierra          75      BO  1595628465        82 -17.80
# ..                       ...         ...     ...         ...       ...    ...
# 551                    Lodja          10      CD  1595628638        63  -3.48
# 552                   Vanimo          92      PG  1595628567        79  -2.67
# 553                   Tommot          87      RU  1595628638        91  58.96
# 554                     Nuuk          75      GL  1595628587        71  64.18
# 555                  Klyuchi           2      RU  1595628534        95  52.27
#
#         Lng  Max Temp  Wind Speed
# 0    150.47     45.00        2.24
# 1    130.99     41.00       10.29
# 2   -155.09     82.40       12.75
# 3     12.61     87.76        4.63
# 4    -63.17     59.00        4.70
# ..      ...       ...         ...
# 551   23.43     73.31        1.16
# 552  141.30     79.63        5.48
# 553  126.29     62.62        2.26
# 554  -51.72     55.40        4.70
# 555   79.17     59.65        3.02
#
# [556 rows x 9 columns]

# %%
# Save city data into a csv file
weather_dict.to_csv("output_data/cities.csv", index = False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Max Temp"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Max Temperature (04/01/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Images/City Latitude vs Max Temperature.png")

# %% [markdown]
# #### Highest temperature is found at 0 latitude and as the latidude increases or decreases, temperature drops.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create Latitude vs. Humidity Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Humidity"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Humidity (04/01/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Humidity (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Images/City Latitude vs Humidity.png")

# %% [markdown]
# #### Polar regions have lower humidity and as latitude gets higher,humidity gets higher in southern hemisphere.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create Latitude vs. Cloudiness Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Cloudiness (04/01/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Cloudiness (%)")

# Set y axis limit
plt.ylim(-5,105)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# #### Cloudiness data is widely spread across the latitude.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create Latitude vs. Wind Speed scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Wind Speed"], facecolor = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (mph) (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Wind Speed (%)")

# Set y axis limit
plt.ylim(-2,50)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Images/City Latitude vs Wind Speed (mph).png")

# %% [markdown]
# #### Wind speed data is widely spread across the latitude.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linear_agression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_dict.loc[weather_dict["Lat"] >= 0]
southern_hemisphere = weather_dict.loc[weather_dict["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, 0, 0)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.69

# %% [markdown]
# #### There is a strong negative correlation between latitude and max temperature for northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.82

# %% [markdown]
# #### There is a moderate positive correlation between latitude and max temperature for southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.02

# %% [markdown]
# #### There is a weak negative correlation between latitude and humidity for northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, -40, 50)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.02

# %% [markdown]
# #### There is a weak negative correlation between latitude and humidity for southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.03

# %% [markdown]
# #### There is a weak negative correlation between latitude and cloudiness for northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.04

# %% [markdown]
# #### There is a weak negative correlation between latitude and cloudiness for southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, 40, 20)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.06

# %% [markdown]
# #### There is a weak negative correlation between latitude and windspeed for northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, -30, 15)

# Set  title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.03

# %% [markdown]
# #### There is a weak negative correlation between latitude and wind speed for southern hemisphere.
